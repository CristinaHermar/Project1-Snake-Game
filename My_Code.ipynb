# %% [markdown]
# # Pseudocódigo

# %% [markdown]
# importar módulo turtle para cuerpo de serpiente \
# importar módulo time para tiempo de desplazamiento \
# importar módulo random para que comida aparezca en otro lado \
#
# posponer = 0.1 variable para que snake no vaya tan rápdio y corra a una milésima de segundo\
#
# Configuración de ventana. \
# ventana = del módulo turtle asignar .screen()\
# ventana. asignar title ("Snake")\
# ventana. asignar .bgcolor (" ")\
# ventana. asignar .setup para tamaño (with = a, height = a)\
# ventana. asignar tracer\
#
# Configuración de snake\
# snake = asignar de módulo turtle .turtle\
# snake = módulo turtle con función turtle()\
# snake asignar .speed (o) para que al inicio esté fija\
# snake asignar .bgcolor (" ")\
# snake asignar .shape() para la forma de la serpiente\
# snake asignar .penup() para no dejar rastro en desplazamiento de turtle\
# snake asignar .goto(0,0) para empezar en centro de la pantalla\
# snake asignar .direction con stop para que no se mueva hasta recibir indicación\
#
# Configuración de comida\
# food = módulo turtle con función turtle()\
# food asignar .speed (o) para que al inicio esté fija\
# food asignar .bgcolor (" ")\
# food asignar .shape() para la forma de la serpiente\
# food asignar .penup() para no dejar rastro en desplazamiento de turtle\
# food asignar .goto(0,100) para que no empiece también en el centro\
#
#
# snakes =[] Crear cuerpo de snake con lista vacía \
#
# Crear función de comandos de teclado\
# def arriba (): \
#     snake llamar función direction = "up"\
#
# def abajo (): \
#     snake llamar función direction = "down"\
#
# def left (): \
#     snake llamar función direction = "left"\
#
# def derecha (): \
#     snake llamar función direction = "right"\
#
# Crear función de movimiento para snake\
# def mov(): \
#     si snake tiene .direccion == hacia arriba en vez de stop: \
#          y = obtener ubicación actual con ycor() \
#          actualizar valor de snake con .setyet() y + cantidad de pixeles)\
#
#     si snake tiene .direccion == hacia abajo en vez de stop: \
#         y = obtener ubicación actual con ycor() \
#         actualizar valor de snake con .setyet() y - cantidad de pixeles)\
#
#
#     si snake tiene .direccion == izquierda en vez de stop:\
#         x = obtener ubicación actual con xcor() para mover en x\
#         actualizar valor de snake con .setxet() x - cantidad de pixeles)\
#
#     si snake tiene .direccion == derecha en vez de stop: \
#         x = obtener ubicación actual con xcor() para mover en x\
#         actualizar valor de snake con .setxet() x + cantidad de pixeles)\
#
#
# Instrucciones en teclado\
# ventana  llamar función .listen()\
# #con mayúsculas para decir que es teclado\
# ventana  llamar función .onkeypress(arriba,"Up") \
# ventana  llamar función .onkeypress(abajo,"Down")\
# ventana  llamar función .onkeypress(izquierda,"Left")\
# ventana  llamar función .onkeypress(derecha,"Right")\
#
#
#
# while bucle principal de juego True: \
#     ventana. hasta recibir update()\
#
#      Revisar distancia de cabeza con comida\
#      si snake llamando a función .distance(está lejos de comida) con una distancia < a 20:\  se tocan, si es mayor aún no se tocan porque la comida y la snake miden 20 x20\
#      x= random.randint (-280,280) para que aparezca en algún lugar random en x\
#      y= random.randint (-280,280) para que aparezca en algún lugar random en y\
#      food  llama a función .goto(x,y) para que actualice valor randome y aparezca comida\
#
#      nuevo_segmento = módulo turtle con función turtle()\
#      nuevo_segmento .speed (o) para que al inicio esté fija\
#      nuevo_segmento .bgcolor (" ")\
#      nuevo_segmento .shape() para la forma de la serpiente\
#      nuevo_segmento .penup() para no dejar rastro en desplazamiento de turtle\
#      snakes.append para agregar el (nuevo_segmento)\
#
#
#  Mover el cuerpo de la serpiente\
#  totalSeg = len(segmentos) #empieza en el cero pero cuenta como 1\
#  for index in range (totalSeg -1, 0, -1) #el menos uno es porque el cero cuenta como uno:\
#     obtengo coordenada de elemento anterior para que sigan \
#     index
#     x= segmentos [index - 1].xcor()\
#     y= segmentos [index - 1].ycor()\
#     segmentos [index].goto(x,y)\
#
#   Para mover primer elemento de lista\
#     Si totalseg es mayor a 0: \
#        entonces que se mueva a donde está la snake x = snake.xcor()\
#        entonces que se mueva a donde está la snake x = snake.xcor()
#
#
#
#
#     mov()
#
# de la librería time llamar función .sleep y llamar a posponer (definido antes) para que \no se mueva tan rápido

# %% [markdown]
# # Diagrama de flujo

# %%
from IPython.display import Image
Image("/Users/cris/Desktop/Diagrama de flujo.jpeg")
